# %% [markdown]
# <a href="https://colab.research.google.com/github/leandroboteon/python-correlacoes-precos-apartamento/blob/main/Relacoes_de_precos_de_apartamentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Explorando a Correlação de Preços de Apartamentos**

# %%
# %pip install plotly
# %pip install cufflinks
# %pip install chart-studio

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import chart_studio.plotly as py
import cufflinks as cf
import plotly.graph_objects as go
import plotly.express as px

# %%
df_apto = pd.read_csv("/content/drive/MyDrive/Formação em Dados/Iniciando na Análise/USA_Housing.csv", sep=",")

# %%
df_apto
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
# análise do dataframe -- describe e boxplot
# limpeza e tratamento
# correlações gráficas e histograma
